# %%
#zaimportowanie potrzebnych bibliotek
import pandas as pd
pd.set_option('display.max_columns', 50)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#wczytanie pliku
df=pd.read_csv("/home/mm/Desktop/projekt/nonamezzz/Projekt Python/IBM_HR.csv")

# %%
#podstawowe info o kolumnach, rodzaj danych, ilość danych, sprawdzenie czy NULL
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# 10 pierwszych wierszy z tabeli
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
# podstawowy opis danych (mediana, średnia, min, max, kwartyle)
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#korelacje (metoda Perason'a)
f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.2f',ax=ax, cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
#korelacje (metoda Perason'a) z odrzuconymi wartościami Standard Hours i Employee Count (identycnze wartości)
df_corr=df.drop(['StandardHours', 'EmployeeCount'], axis=1)
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df_corr.corr(), annot=True, linewidths=.5, fmt= '.2f',ax=ax, cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
#histogramy
for x in df:
    try:
        df.hist(column= x)
    except ValueError:
        pass
# Out:
# /home/mm/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:218: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)

# %% [markdown]
# **Age** - wiek pracownika (18 - 60)
#
# **Attrition** - Czy pracownik zrezygnował z pracy na własną decyzję? ('YES', 'NO')
#
# **BusinessTravel**  - częstotliwość podróży służbowych ('Travel\_Rarely', 'Travel\_Frequently', 'Non-Travel')
#
# ~~**DailyRate**~~ - stawka dzienna - brak korelacji z monthly rate i hourly rate  - (102-1499) $?
#
# **Department** - Dział (Departament) ('Sales', 'Research & Development' 'Human Resources')
#
# **DistanceFromHome** - Odległość od domu, im mniejsza liczba tym bliżej z domu do pracy (z zakresu 1-29) mile - ale to tylko w jednym opisie było przypuszczenie.
#
# **Education** - Poziom Edukacji skala 5-stopniowa, 1 'Below College' 2 'College' 3 'Bachelor' 4 'Master' 5 'Doctor'(1-5)
#
# **EducationField** - Dziedzina(obszar) edukacji - ('Life Sciences', 'Other', 'Medical', 'Marketing', 'Technical Degree', 'Human Resources')
#
# ~~**EmployeeCount**~~ - Zliczenie pracownika -wartość zawsze równa 1 - do pominięcia we wszystkich analizach raczej(1)
#
# **EmployeeNumber** - nr pracownika (z zakresu 1-2068)
#
# **EnvironmentSatisfaction** - zadowolenie z środowiska pracy - skala 4-stopniowa 1 'Low' 2 'Medium' 3 'High'
# 4 'Very High' (1-4)
#
# **Gender** - płeć ('Male', 'Female')
#
# ~~**HourlyRate**~~ - stawka godzinowa brak korelacji z dailyrate i z monthlyrate(z zakresu 30-100) $?
#
# **JobInvolvement** - zaangażowanie w pracę - skala 4-stopniowa 1 'Low' 2 'Medium' 3 'High' 4 'Very High'(1-4)
#
# **JobLevel**- Poziom zatrudnienia (pozycji) skala 5-stopniowa (1-5)
#
# **JobRole** - stanowisko ('Sales Executive', 'Research Scientist', 'Laboratory Technician', 'Manufacturing Director', 'Healthcare Representative', 'Manager', 'Sales Representative', 'Research Director', 'Human Resources')
#
# **JobSatisfaction** - zadowolenie z pracy - skala 4-stopniowa 1 'Low' 2 'Medium' 3 'High' 4 'Very High'(1-4)
#
# **MaritalStatus** - stan cywilny ('Single', 'Married', 'Divorced')
#
# **MonthlyIncome** - prawdopodobnie pensja - skupiłbym się na tym parametrze - on wykazuje bardzo dużą korelację z JobLevel i z liczbą przepracowanych lat co ma duży sens. (z zakresu 1009-19999) $?
#
# ~~**MonthlyRate**~~ - ciężko stwierdzić - może dodatkowe wydatki na pracownika, koszt pracownika oprócz pensji???? (z zakresu 2094-26999) nie ma żadnej korelacji z monthly income, daily rate, hourly rate
#
# **NumCompaniesWorked** - sumaryczna libcza firm, w której pracował dany pracownik (1-9)
#
# ~~**Over18**~~ - czy powyżej 18 roku życia - wszystkie dane to Y (Y) - można pominąć
#
# **OverTime** - praca ponadwymiarowa ('Yes', 'No')
#
# **PercentSalaryHike** - procentowa podwyżka w stosunku do roku poprzedniego
#
# **PerformanceRating** - ocena pracownika / wydajności pracownika - skala 4-stopniowa 1 'Low'2 'Good' 3 'Excellent' 4 'Outstanding' (3-4)
#
# **RelationshipSatisfaction** - zadowolenie z relacji (raczej z innymi pracownikami)- skala 4-stopniowa 1 'Low' 2 'Medium' 3 'High' 4 'Very High' (1-4)
#
# ~~**StandardHours**~~ - standardowe godziny pracy/miesiąc? - ciężko stwierdzić, co to jest z racji, że jest to dla wszystkich taka sama liczba - 80 godzin i myślę, że nie będzie to przydatne w żadnych analizach - do pominięcia (80)
#
# **StockOptionLevel** - opcje akcji dla pracowników w skali 3-stopniowej od zera, przypuszczam 0 - brak akcji (0-3)
#
# **TotalWorkingYears** - sumaryczny czas pracy pracownika u wszystkich pracodawców (z zakresu 0 - 40) lata
#
# **TrainingTimesLastYear** - ilość szkoleń podczas ostatniego roku (0-6) razy
#
# **WorkLifeBalance** - ocena balansu praca/życie w skali 4-stopniowej 1 'Bad' 2 'Good' 3 'Better' 4 'Best' (1-4)
#
# **YearsAtCompany** - ilość lat w tej firmie (z zakresu 0-40) lat
#
# **YearsInCurrentRole** - ilość lat w danej roli/na danym stanowisku (0-18) lat
#
# **YearsSinceLastPromotion** - ilość lat od ostatniego awansu (0-15) lat
#
# **YearsWithCurrManager** - ilość lat przepracowanych pod obencym menadżerem (0-17) lat

# %%
#do opisu danych, wartości min,max i wartości unikalne
for column in df:
    print(column, "min-", df[column].min(), "max-", df[column].max(), "unique values-", df[column].unique())
    print('')
# Out:
# Age min- 18 max- 60 unique values- [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
#
# Attrition min- No max- Yes unique values- ['Yes' 'No']
#
# BusinessTravel min- Non-Travel max- Travel_Rarely unique values- ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
# DailyRate min- 102 max- 1499 unique values- [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
# ...
